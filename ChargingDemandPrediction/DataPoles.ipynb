# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pylab 
from datetime import datetime, timedelta
import numpy as np
import json

# %%
data0121 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_011121.csv')
data0221 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_020121.csv')
data0321 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_030121.csv')
data0421 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_040121.csv')
data0521 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_050121.csv')
data0621 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_060121.csv')
data0721 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_070121.csv')
data0821 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_080121.csv')
data0921 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_090121.csv')
data1021 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_100121.csv')
data1121 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_110121.csv')
data1221 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_120121.csv')
data0122 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_010122.csv')
data0222 = pd.read_csv(r'../../Data_HAN/Data_csv/measurements_020122.csv')

# %%
data = pd.concat([data0121,data0221,data0321,data0421,data0521,data0621,data0721,data0821,data0921,data1021,data1121,data1221,data0122,data0222])

# %%
data
# Out:
#                 V1          V2          V3         I1   I2   I3    P    E  \
# 0       232.790000  221.780000    0.000000   5.500000  5.0  2.0  0.0  0.0
# 1       232.790000  221.780000    0.000000   5.500000  5.0  2.0  0.0  0.0
# 2       225.623032  229.307861  229.752029  15.090841  0.0  0.0  NaN  NaN
# 3       225.653503  229.340149  229.879105  15.047119  0.0  0.0  NaN  NaN
# 4       225.965988  229.547592  229.955185  15.034362  0.0  0.0  NaN  NaN
# ...            ...         ...         ...        ...  ...  ...  ...  ...
# 315231  233.496719  233.193848  232.661682   0.000000  0.0  0.0  NaN  NaN
# 315232  232.316650  233.075394  233.334839   0.000000  0.0  0.0  NaN  NaN
# 315233  232.366928  233.071945  233.318848   0.000000  0.0  0.0  NaN  NaN
# 315234  233.622818  233.186905  232.376389   0.000000  0.0  0.0  NaN  NaN
# 315235  233.588608  233.307663  232.821167   0.000000  0.0  0.0  NaN  NaN
#
#                 F        Time  SoC  socketId userId userName  carId  \
# ...

# %%
socket1_data = data[data.socketId == 1]
socket1_data.reset_index(drop=True, inplace=True)
socket1_data
# Out:
#                 V1          V2          V3         I1   I2   I3   P   E  \
# 0       225.623032  229.307861  229.752029  15.090841  0.0  0.0 NaN NaN
# 1       225.653503  229.340149  229.879105  15.047119  0.0  0.0 NaN NaN
# 2       225.965988  229.547592  229.955185  15.034362  0.0  0.0 NaN NaN
# 3       225.685806  229.095520  229.577774  15.233005  0.0  0.0 NaN NaN
# 4       226.078812  229.529602  229.999420  15.219460  0.0  0.0 NaN NaN
# ...            ...         ...         ...        ...  ...  ...  ..  ..
# 935298  232.171021  232.948212  233.245697   0.000000  0.0  0.0 NaN NaN
# 935299  232.319992  233.059616  233.195251   0.000000  0.0  0.0 NaN NaN
# 935300  232.113235  233.048355  233.153381   0.000000  0.0  0.0 NaN NaN
# 935301  232.381287  233.108566  233.383957   0.000000  0.0  0.0 NaN NaN
# 935302  232.366928  233.071945  233.318848   0.000000  0.0  0.0 NaN NaN
#
#                 F        Time  SoC  socketId userId userName  carId carName
# ...

# %%
socket2_data = data[data.socketId == 2]
socket2_data.reset_index(drop=True, inplace=True)
socket2_data
# Out:
#                 V1          V2          V3   I1         I2        I3    P  \
# 0       232.790000  221.780000    0.000000  5.5   5.000000  2.000000  0.0
# 1       232.790000  221.780000    0.000000  5.5   5.000000  2.000000  0.0
# 2       227.512039  224.345825  230.519867  0.0  30.545050  0.160401  NaN
# 3       228.074020  223.299713  230.841431  0.0  30.702589  0.156208  NaN
# 4       228.173523  223.397827  230.970963  0.0  30.682295  0.154858  NaN
# ...            ...         ...         ...  ...        ...       ...  ...
# 934960  232.063370  232.822556  233.193985  0.0   0.000000  0.000000  NaN
# 934961  232.213654  232.878693  233.119995  0.0   0.000000  0.000000  NaN
# 934962  232.179520  233.064987  233.234070  0.0   0.000000  0.000000  NaN
# 934963  232.260864  232.856110  233.125351  0.0   0.000000  0.000000  NaN
# 934964  232.316650  233.075394  233.334839  0.0   0.000000  0.000000  NaN
#
#           E          F        Time  SoC  socketId userId userName  carId  \
# ...

# %%
socket3_data = data[data.socketId == 3]
socket3_data.reset_index(drop=True, inplace=True)
socket3_data
# Out:
#                 V1          V2          V3   I1   I2   I3   P   E          F  \
# 0       229.876724  229.356064  229.486649  0.0  0.0  0.0 NaN NaN  50.023697
# 1       229.963303  229.394592  229.620834  0.0  0.0  0.0 NaN NaN  50.030285
# 2       229.763107  229.164703  229.289383  0.0  0.0  0.0 NaN NaN  50.016613
# 3       229.716736  229.222870  229.067612  0.0  0.0  0.0 NaN NaN  50.036419
# 4       230.026764  229.381134  229.474869  0.0  0.0  0.0 NaN NaN  50.026608
# ...            ...         ...         ...  ...  ...  ...  ..  ..        ...
# 911439  233.425995  233.061584  232.538361  0.0  0.0  0.0 NaN NaN  49.979511
# 911440  233.445633  233.241577  232.803650  0.0  0.0  0.0 NaN NaN  50.013515
# 911441  233.417877  233.260818  232.499756  0.0  0.0  0.0 NaN NaN  50.007492
# 911442  233.496719  233.193848  232.661682  0.0  0.0  0.0 NaN NaN  49.992325
# 911443  233.588608  233.307663  232.821167  0.0  0.0  0.0 NaN NaN  50.039127
#
# ...

# %%
socket4_data = data[data.socketId == 4]
socket4_data.reset_index(drop=True, inplace=True)
socket4_data
# Out:
#                 V1          V2          V3   I1   I2   I3   P   E          F  \
# 0       230.059402  229.401154  229.175659  0.0  0.0  0.0 NaN NaN  50.023697
# 1       230.015472  229.274704  229.204697  0.0  0.0  0.0 NaN NaN  50.030285
# 2       229.921906  229.178345  229.033295  0.0  0.0  0.0 NaN NaN  50.023552
# 3       230.001892  229.349106  228.882370  0.0  0.0  0.0 NaN NaN  50.036419
# 4       230.211548  229.442139  229.206268  0.0  0.0  0.0 NaN NaN  50.026608
# ...            ...         ...         ...  ...  ...  ...  ..  ..        ...
# 911429  233.496689  232.999939  232.160095  0.0  0.0  0.0 NaN NaN  49.983101
# 911430  233.501556  233.169006  232.416321  0.0  0.0  0.0 NaN NaN  50.011417
# 911431  233.462036  233.170563  232.131302  0.0  0.0  0.0 NaN NaN  50.007153
# 911432  233.694687  233.238129  232.408173  0.0  0.0  0.0 NaN NaN  49.992325
# 911433  233.622818  233.186905  232.376389  0.0  0.0  0.0 NaN NaN  50.039127
#
# ...

# %%
socket1=socket1_data.drop(['P','E','F','SoC','socketId','userId','userName','carId','carName'], axis=1)
socket2=socket2_data.drop(['P','E','F','SoC','socketId','userId','userName','carId','carName'], axis=1)
socket3=socket3_data.drop(['P','E','F','SoC','socketId','userId','userName','carId','carName'], axis=1)
socket4=socket4_data.drop(['P','E','F','SoC','socketId','userId','userName','carId','carName'], axis=1)

# %%
socket1
# Out:
#                 V1          V2          V3         I1   I2   I3        Time
# 0       225.623032  229.307861  229.752029  15.090841  0.0  0.0  1607419478
# 1       225.653503  229.340149  229.879105  15.047119  0.0  0.0  1607419508
# 2       225.965988  229.547592  229.955185  15.034362  0.0  0.0  1607419538
# 3       225.685806  229.095520  229.577774  15.233005  0.0  0.0  1607419568
# 4       226.078812  229.529602  229.999420  15.219460  0.0  0.0  1607419599
# ...            ...         ...         ...        ...  ...  ...         ...
# 935298  232.171021  232.948212  233.245697   0.000000  0.0  0.0  1643677263
# 935299  232.319992  233.059616  233.195251   0.000000  0.0  0.0  1643677293
# 935300  232.113235  233.048355  233.153381   0.000000  0.0  0.0  1643677323
# 935301  232.381287  233.108566  233.383957   0.000000  0.0  0.0  1643677353
# 935302  232.366928  233.071945  233.318848   0.000000  0.0  0.0  1643677383
#
# [935303 rows x 7 columns]

# %%
def markVoltNaN(inVolt):
    if (inVolt < -300) or (inVolt > 300):
        return np.NaN
    return inVolt

def markAmpreNaN(inAmp):
    if (inAmp < -30) or (inAmp > 30):
        return np.NaN
    return inAmp

def setIndextoTime(data_in):
    data_out = data_in
    
    data_out['V1'] = data_in['V1'].map(markVoltNaN)
    data_out['V2'] = data_in['V2'].map(markVoltNaN)
    data_out['V3'] = data_in['V3'].map(markVoltNaN)
    
    data_out['I1'] = data_in['I1'].map(markAmpreNaN)
    data_out['I2'] = data_in['I2'].map(markAmpreNaN)
    data_out['I3'] = data_in['I3'].map(markAmpreNaN)
    
    data_out = data_out.fillna(method='ffill')
    
    data_out.loc[:,'Time'] = pd.to_datetime(data_out.loc[:,'Time'],unit='s')
    data_out.set_index(['Time'], inplace=True)
    data_out.sort_index(inplace=True)
    data_out.loc[:,'Time_diff'] = (data_out.index.to_series().diff()).dt.total_seconds()
    return data_out

# %%
socket1 = setIndextoTime(socket1)

# %%
socket1
# Out:
#                              V1          V2          V3         I1   I2   I3  \
# Time
# 2020-12-08 09:24:38  225.623032  229.307861  229.752029  15.090841  0.0  0.0
# 2020-12-08 09:25:08  225.653503  229.340149  229.879105  15.047119  0.0  0.0
# 2020-12-08 09:25:38  225.965988  229.547592  229.955185  15.034362  0.0  0.0
# 2020-12-08 09:26:08  225.685806  229.095520  229.577774  15.233005  0.0  0.0
# 2020-12-08 09:26:39  226.078812  229.529602  229.999420  15.219460  0.0  0.0
# ...                         ...         ...         ...        ...  ...  ...
# 2022-02-01 01:01:03  232.171021  232.948212  233.245697   0.000000  0.0  0.0
# 2022-02-01 01:01:33  232.319992  233.059616  233.195251   0.000000  0.0  0.0
# 2022-02-01 01:02:03  232.113235  233.048355  233.153381   0.000000  0.0  0.0
# 2022-02-01 01:02:33  232.381287  233.108566  233.383957   0.000000  0.0  0.0
# 2022-02-01 01:03:03  232.366928  233.071945  233.318848   0.000000  0.0  0.0
#
#                      Time_diff
# Time
# ...

# %%
socket1.loc[socket1.Time_diff>-1000, 'Time_diff'].plot(figsize=(100,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
socket1.reset_index().plot(x='Time',y='Time_diff',kind='scatter', logy=True)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Time_diff'>

# %%
len(socket1.loc[socket1.Time_diff<1000])
# Out:
# 935208

# %%
socket2 = setIndextoTime(socket2)
socket3 = setIndextoTime(socket3)
socket4 = setIndextoTime(socket4)

# %%
socket2.reset_index().plot(x='Time',y='Time_diff',kind='scatter', logy=True)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Time_diff'>

# %%
plt.rcParams.update({'font.size': 12})
socket2.reset_index().plot(x='Time',y='Time_diff',kind='scatter', logy=True)
plt.pyplot.xticks(rotation=45)
plt.pyplot.savefig('Pole_timediff.png', bbox_inches="tight")

# %%
socket3.reset_index().plot(x='Time',y='Time_diff',kind='scatter', logy=True)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Time_diff'>

# %%
''' If the time diff is larger than 600s (10 minutes), then data are assumed loss and E is 0 '''

def removeLargeDiff(diff_in):
    if (diff_in > 600):
        return 0
    return diff_in

def calculateEnergy(data_in):
    data_out = data_in.copy()
    data_out['Power'] = data_out['I1']*data_out['V1'] + data_out['I2']*data_out['V2'] + data_out['I3']*data_out['V3']
    data_out.loc[:,'Time_diff'] = data_out.Time_diff.shift(-1)
    data_out = data_out.iloc[:-1,:]
    data_out['Time_diff'] = data_out.Time_diff.map(removeLargeDiff)
    data_out['Energy_kWh'] = data_out['Power'] * data_out['Time_diff'] / 3600000
    data_out = data_out[['Energy_kWh']].groupby(pd.Grouper(freq='1H')).sum()
    return data_out

# %%
socket1_hourly = calculateEnergy(socket1)

# %%
socket1_hourly.plot(figsize = (100,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
socket1_hourly
# Out:
#                      Energy_kWh
# Time
# 2020-12-08 09:00:00    2.008097
# 2020-12-08 10:00:00    2.505309
# 2020-12-08 11:00:00    0.078888
# 2020-12-08 12:00:00    0.000000
# 2020-12-08 13:00:00    0.115595
# ...                         ...
# 2022-01-31 21:00:00    0.000000
# 2022-01-31 22:00:00    0.000000
# 2022-01-31 23:00:00    0.000000
# 2022-02-01 00:00:00    0.000000
# 2022-02-01 01:00:00    0.000000
#
# [10073 rows x 1 columns]

# %%
socket2_hourly = calculateEnergy(socket2)
socket3_hourly = calculateEnergy(socket3)
socket4_hourly = calculateEnergy(socket4)

# %%
socket2_hourly.plot(figsize = (100,6))
socket3_hourly.plot(figsize = (100,6))
socket4_hourly.plot(figsize = (100,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
socket2_hourly
# Out:
#                      Energy_kWh
# Time
# 2020-11-26 13:00:00         0.0
# 2020-11-26 14:00:00         0.0
# 2020-11-26 15:00:00         0.0
# 2020-11-26 16:00:00         0.0
# 2020-11-26 17:00:00         0.0
# ...                         ...
# 2022-01-31 21:00:00         0.0
# 2022-01-31 22:00:00         0.0
# 2022-01-31 23:00:00         0.0
# 2022-02-01 00:00:00         0.0
# 2022-02-01 01:00:00         0.0
#
# [10357 rows x 1 columns]

# %%
socket3_hourly
# Out:
#                      Energy_kWh
# Time
# 2021-01-08 12:00:00         0.0
# 2021-01-08 13:00:00         0.0
# 2021-01-08 14:00:00         0.0
# 2021-01-08 15:00:00         0.0
# 2021-01-08 16:00:00         0.0
# ...                         ...
# 2022-01-31 21:00:00         0.0
# 2022-01-31 22:00:00         0.0
# 2022-01-31 23:00:00         0.0
# 2022-02-01 00:00:00         0.0
# 2022-02-01 01:00:00         0.0
#
# [9326 rows x 1 columns]

# %%
socket4_hourly
# Out:
#                      Energy_kWh
# Time
# 2021-01-08 12:00:00         0.0
# 2021-01-08 13:00:00         0.0
# 2021-01-08 14:00:00         0.0
# 2021-01-08 15:00:00         0.0
# 2021-01-08 16:00:00         0.0
# ...                         ...
# 2022-01-31 21:00:00         0.0
# 2022-01-31 22:00:00         0.0
# 2022-01-31 23:00:00         0.0
# 2022-02-01 00:00:00         0.0
# 2022-02-01 01:00:00         0.0
#
# [9326 rows x 1 columns]

# %%
data_hourly = socket1_hourly.loc['2021-01-08 12:00:00':,:] + socket2_hourly.loc['2021-01-08 12:00:00':,:] + socket3_hourly.loc['2021-01-08 12:00:00':,:] + socket4_hourly.loc['2021-01-08 12:00:00':,:]

# %%
data_hourly.plot(figsize=(100,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data_hourly['weekday']=data_hourly.index.day_of_week
data_hourly['hour']=data_hourly.index.hour

# %%
import holidays
data_hourly['hols'] = pd.Series(data_hourly.index).apply(lambda x: holidays.CountryHoliday('NL').get(x)).values

# %%
# Add HAN breaks
# https://www.hanuniversity.com/en/study-and-living/studying-at-han/academic-calendar/#
# https://schoolholidayseurope.eu/school-holidays-holland/
data_hourly.loc[(data_hourly.index > '2021-02-14 23:00:00') & (data_hourly.index < '2021-02-22 00:00:00'), 'hols'] = 'Spring holiday'
data_hourly.loc[(data_hourly.index > '2021-05-02 23:00:00') & (data_hourly.index < '2021-05-10 00:00:00'), 'hols'] = 'May holiday'
data_hourly.loc[(data_hourly.index > '2021-07-11 23:00:00') & (data_hourly.index < '2021-08-16 00:00:00'), 'hols'] = 'Summer break'
data_hourly.loc[(data_hourly.index > '2021-10-24 23:00:00') & (data_hourly.index < '2021-11-01 00:00:00'), 'hols'] = 'Fall holiday'
data_hourly.loc[(data_hourly.index > '2020-12-20 23:00:00') & (data_hourly.index < '2021-01-04 00:00:00'), 'hols'] = 'Winter break'
data_hourly.loc[(data_hourly.index > '2021-12-23 23:00:00') & (data_hourly.index < '2022-01-10 00:00:00'), 'hols'] = 'Winter break'

# %%
data_hourly['is_hol'] = ~data_hourly.isna()['hols']

# %%
# Covid data
R_value = pd.read_json(r'./Rvalue.json', orient='split')
R_value.loc[R_value.Rt_avg.isna(), 'Rt_avg'] = (R_value.loc[R_value.Rt_avg.isna(), 'Rt_low'] + R_value.loc[R_value.Rt_avg.isna(), 'Rt_up'])/2
R_value.set_index(['Date'], inplace=True)

data_hourly['R'] = np.NaN
for i in range(len(data_hourly)):
    data_hourly.loc[str(data_hourly.index.date[i]), 'R'] = R_value.loc[str(data_hourly.index.date[i]),'Rt_avg']
    
data_hourly
# Out:
#                      Energy_kWh  weekday  hour  hols  is_hol     R
# Time
# 2021-01-08 12:00:00    0.187918        4    12  None   False  0.92
# 2021-01-08 13:00:00    0.000000        4    13  None   False  0.92
# 2021-01-08 14:00:00    0.000000        4    14  None   False  0.92
# 2021-01-08 15:00:00    0.000000        4    15  None   False  0.92
# 2021-01-08 16:00:00    0.000000        4    16  None   False  0.92
# ...                         ...      ...   ...   ...     ...   ...
# 2022-01-31 21:00:00    0.000000        0    21  None   False  0.96
# 2022-01-31 22:00:00    0.000000        0    22  None   False  0.96
# 2022-01-31 23:00:00    0.000000        0    23  None   False  0.96
# 2022-02-01 00:00:00    0.000000        1     0  None   False  0.93
# 2022-02-01 01:00:00    0.000000        1     1  None   False  0.93
#
# [9326 rows x 6 columns]

# %%
ic = pd.read_csv(r'./COVID-19_ic_opnames.csv', sep=';')
ic['Date_of_statistics'] = pd.to_datetime(ic['Date_of_statistics'])
ic.set_index(['Date_of_statistics'], inplace=True)

data_hourly['IC_number'] = np.NaN
for i in range(len(data_hourly)):
    data_hourly.loc[str(data_hourly.index.date[i]), 'IC_number'] = ic.loc[str(data_hourly.index.date[i]),'IC_admission']
    
data_hourly
# Out:
#                      Energy_kWh  weekday  hour  hols  is_hol     R  IC_number
# Time
# 2021-01-08 12:00:00    0.187918        4    12  None   False  0.92       45.0
# 2021-01-08 13:00:00    0.000000        4    13  None   False  0.92       45.0
# 2021-01-08 14:00:00    0.000000        4    14  None   False  0.92       45.0
# 2021-01-08 15:00:00    0.000000        4    15  None   False  0.92       45.0
# 2021-01-08 16:00:00    0.000000        4    16  None   False  0.92       45.0
# ...                         ...      ...   ...   ...     ...   ...        ...
# 2022-01-31 21:00:00    0.000000        0    21  None   False  0.96       20.0
# 2022-01-31 22:00:00    0.000000        0    22  None   False  0.96       20.0
# 2022-01-31 23:00:00    0.000000        0    23  None   False  0.96       20.0
# 2022-02-01 00:00:00    0.000000        1     0  None   False  0.93       15.0
# 2022-02-01 01:00:00    0.000000        1     1  None   False  0.93       15.0
#
# [9326 rows x 7 columns]

# %%
data_hourly['measure'] = np.NaN
data_hourly.loc[data_hourly.index < '2021-04-28', 'measure'] = 1
data_hourly.loc[(data_hourly.index < '2021-06-05') & (data_hourly.index > '2021-04-27'),'measure'] = 0.75
data_hourly.loc[(data_hourly.index < '2021-07-15') & (data_hourly.index > '2021-06-04'),'measure'] = 0.5
data_hourly.loc[(data_hourly.index < '2021-09-01') & (data_hourly.index > '2021-07-14'),'measure'] = 0.75
data_hourly.loc[(data_hourly.index < '2022-01-26') & (data_hourly.index > '2021-08-31'),'measure'] = 0.5
data_hourly.loc[(data_hourly.index > '2022-01-25'),'measure'] = 0.25

# %%
data_hourly
# Out:
#                      Energy_kWh  weekday  hour  hols  is_hol     R  IC_number  \
# Time
# 2021-01-08 12:00:00    0.187918        4    12  None   False  0.92       45.0
# 2021-01-08 13:00:00    0.000000        4    13  None   False  0.92       45.0
# 2021-01-08 14:00:00    0.000000        4    14  None   False  0.92       45.0
# 2021-01-08 15:00:00    0.000000        4    15  None   False  0.92       45.0
# 2021-01-08 16:00:00    0.000000        4    16  None   False  0.92       45.0
# ...                         ...      ...   ...   ...     ...   ...        ...
# 2022-01-31 21:00:00    0.000000        0    21  None   False  0.96       20.0
# 2022-01-31 22:00:00    0.000000        0    22  None   False  0.96       20.0
# 2022-01-31 23:00:00    0.000000        0    23  None   False  0.96       20.0
# 2022-02-01 00:00:00    0.000000        1     0  None   False  0.93       15.0
# 2022-02-01 01:00:00    0.000000        1     1  None   False  0.93       15.0
#
# ...

# %%
data_hourly['E_1'] = data_hourly['Energy_kWh']
data_hourly['E_2'] = data_hourly['Energy_kWh']
data_hourly['E_3'] = data_hourly['Energy_kWh']
data_hourly['E_1'] = data_hourly.E_1.shift(1)
data_hourly['E_2'] = data_hourly.E_2.shift(2)
data_hourly['E_3'] = data_hourly.E_3.shift(3)
data_hourly
# Out:
#                      Energy_kWh  weekday  hour  hols  is_hol     R  IC_number  \
# Time
# 2021-01-08 12:00:00    0.187918        4    12  None   False  0.92       45.0
# 2021-01-08 13:00:00    0.000000        4    13  None   False  0.92       45.0
# 2021-01-08 14:00:00    0.000000        4    14  None   False  0.92       45.0
# 2021-01-08 15:00:00    0.000000        4    15  None   False  0.92       45.0
# 2021-01-08 16:00:00    0.000000        4    16  None   False  0.92       45.0
# ...                         ...      ...   ...   ...     ...   ...        ...
# 2022-01-31 21:00:00    0.000000        0    21  None   False  0.96       20.0
# 2022-01-31 22:00:00    0.000000        0    22  None   False  0.96       20.0
# 2022-01-31 23:00:00    0.000000        0    23  None   False  0.96       20.0
# 2022-02-01 00:00:00    0.000000        1     0  None   False  0.93       15.0
# 2022-02-01 01:00:00    0.000000        1     1  None   False  0.93       15.0
#
# ...

# %%
data_hourly.to_csv('./charge_hourly_wifi.csv')

# %% [markdown]
# # Prepare data for training

# %%
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab 
from datetime import datetime, timedelta
import numpy as np
from fastai.collab import *
from fastai.tabular.all import *
from time import *

# %%
data = pd.read_csv(r'./charge_hourly_with_Covid_new.csv')
data
# Out:
#                       Time  Energy_kWh  weekday  hour            hols  is_hol  \
# 0      2020-12-02 09:00:00    4.214567        2     9             NaN   False
# 1      2020-12-02 10:00:00    0.560625        2    10             NaN   False
# 2      2020-12-02 11:00:00    0.000000        2    11             NaN   False
# 3      2020-12-02 12:00:00    0.000000        2    12             NaN   False
# 4      2020-12-02 13:00:00    0.000558        2    13             NaN   False
# ...                    ...         ...      ...   ...             ...     ...
# 10883  2022-02-28 20:00:00    0.000000        0    20  Spring holiday    True
# 10884  2022-02-28 21:00:00    0.000000        0    21  Spring holiday    True
# 10885  2022-02-28 22:00:00    0.000000        0    22  Spring holiday    True
# 10886  2022-02-28 23:00:00    0.000000        0    23  Spring holiday    True
# 10887  2022-03-01 00:00:00    0.000000        1     0  Spring holiday    True
#
#        measure       E_1       E_2       E_3
# 0          3.0       NaN       NaN       NaN
# 1          3.0  4.214567       NaN       NaN
# 2          3.0  0.560625  4.214567       NaN
# 3          3.0  0.000000  0.560625  4.214567
# 4          3.0  0.000000  0.000000  0.560625
# ...        ...       ...       ...       ...
# 10883      0.0  0.000000  0.000000  0.000925
# 10884      0.0  0.000000  0.000000  0.000000
# 10885      0.0  0.000000  0.000000  0.000000
# 10886      0.0  0.000000  0.000000  0.000000
# 10887      0.0  0.000000  0.000000  0.000000
#
# [10888 rows x 10 columns]

# %%
data_test = pd.read_csv(r'./charge0422_hourly_with_Covid_new.csv')
data_test
# Out:
#                     Time  Energy_kWh  weekday  hour            hols  is_hol  \
# 0    2022-03-01 04:00:00    0.000000        1     4  Spring holiday    True
# 1    2022-03-01 05:00:00    0.000000        1     5  Spring holiday    True
# 2    2022-03-01 06:00:00    0.044108        1     6  Spring holiday    True
# 3    2022-03-01 07:00:00    7.013325        1     7  Spring holiday    True
# 4    2022-03-01 08:00:00    7.089000        1     8  Spring holiday    True
# ..                   ...         ...      ...   ...             ...     ...
# 647  2022-03-28 03:00:00    0.000000        0     3             NaN   False
# 648  2022-03-28 04:00:00    0.000000        0     4             NaN   False
# 649  2022-03-28 05:00:00    0.000000        0     5             NaN   False
# 650  2022-03-28 06:00:00   15.496425        0     6             NaN   False
# 651  2022-03-28 07:00:00   28.914517        0     7             NaN   False
#
#      measure        E_1       E_2  E_3
# 0          0   0.000000  0.000000  0.0
# 1          0   0.000000  0.000000  0.0
# 2          0   0.000000  0.000000  0.0
# 3          0   0.044108  0.000000  0.0
# 4          0   7.013325  0.044108  0.0
# ..       ...        ...       ...  ...
# 647        0   0.000000  0.000000  0.0
# 648        0   0.000000  0.000000  0.0
# 649        0   0.000000  0.000000  0.0
# 650        0   0.000000  0.000000  0.0
# 651        0  15.496425  0.000000  0.0
#
# [652 rows x 10 columns]

# %%
sequence = data['Energy_kWh'].values
sequence.shape
# Out:
# (10888,)

# %%
test_sequence = data_test['Energy_kWh'].values
test_sequence.shape
# Out:
# (652,)

# %%
#from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler(feature_range=(-1, 1))
#train_data_normalized = scaler.fit_transform(sequence .reshape(-1, 1))

# %%
#train_data_normalized = torch.FloatTensor(train_data_normalized).view(-1)
train_data_normalized = torch.FloatTensor(sequence).view(-1)

# %%
# 7 day = 168 hours
train_window = 168
# predict next 5 hours
out_sz = 5

# %%
def create_inout_sequences(input_data, tw, out_sz):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw-out_sz):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+tw:i+tw+out_sz]
        inout_seq.append((train_seq ,train_label))
    return inout_seq

# %%
train_inout_seq = create_inout_sequences(train_data_normalized, train_window, out_sz)
len(train_inout_seq)
# Out:
# 10715

# %%
train_inout_seq[-5:]
# Out:
# [(tensor([1.4158e-01, 1.0000e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5997e+00, 2.1166e+01, 3.1602e+01,
#           2.7686e+01, 2.0687e+01, 1.3520e+01, 1.1005e+01, 9.9434e+00, 5.5835e+00,
#           9.7125e+00, 6.8815e+00, 8.8997e-01, 3.0550e-01, 3.0641e-01, 1.0294e-01,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.2265e+01, 2.4012e+01,
#           1.9197e+01, 1.3490e+01, 1.3597e+01, 1.3973e+01, 1.2416e+01, 1.7847e+01,
#           1.7965e+01, 1.1426e+01, 4.5538e+00, 7.4827e+00, 7.4327e+00, 2.7716e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 4.4697e+00, 2.6626e+01, 2.9752e+01,
#           1.4703e+01, 5.5771e+00, 5.0182e+00, 7.9568e+00, 1.3544e-01, 3.8480e+00,
#           6.8352e+00, 3.1275e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 3.1861e+00, 1.4603e+01, 2.5838e+01,
#           2.1235e+01, 1.7098e+01, 1.5432e+01, 1.2104e+01, 3.2632e+00, 3.5250e-02,
#           8.4158e-02, 3.6490e-01, 3.2250e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.2492e-02, 0.0000e+00, 0.0000e+00,
#           1.3616e-01, 1.5885e-01, 5.5108e-01, 0.0000e+00, 0.0000e+00, 8.6878e-01,
#           0.0000e+00, 0.0000e+00, 1.0067e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.3118e-01,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.8419e-01, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 2.6583e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0067e+00, 1.7204e+00,
#           0.0000e+00, 1.9109e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#   tensor([0.0473, 0.0071, 0.0009, 0.0000, 0.0000])),
#  (tensor([1.0000e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 1.5997e+00, 2.1166e+01, 3.1602e+01, 2.7686e+01,
#           2.0687e+01, 1.3520e+01, 1.1005e+01, 9.9434e+00, 5.5835e+00, 9.7125e+00,
#           6.8815e+00, 8.8997e-01, 3.0550e-01, 3.0641e-01, 1.0294e-01, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.2265e+01, 2.4012e+01, 1.9197e+01,
#           1.3490e+01, 1.3597e+01, 1.3973e+01, 1.2416e+01, 1.7847e+01, 1.7965e+01,
#           1.1426e+01, 4.5538e+00, 7.4827e+00, 7.4327e+00, 2.7716e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 4.4697e+00, 2.6626e+01, 2.9752e+01, 1.4703e+01,
#           5.5771e+00, 5.0182e+00, 7.9568e+00, 1.3544e-01, 3.8480e+00, 6.8352e+00,
#           3.1275e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 3.1861e+00, 1.4603e+01, 2.5838e+01, 2.1235e+01,
#           1.7098e+01, 1.5432e+01, 1.2104e+01, 3.2632e+00, 3.5250e-02, 8.4158e-02,
#           3.6490e-01, 3.2250e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 1
ensor([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5997e+00,
#           2.1166e+01, 3.1602e+01, 2.7686e+01, 2.0687e+01, 1.3520e+01, 1.1005e+01,
#           9.9434e+00, 5.5835e+00, 9.7125e+00, 6.8815e+00, 8.8997e-01, 3.0550e-01,
#           3.0641e-01, 1.0294e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           1.2265e+01, 2.4012e+01, 1.9197e+01, 1.3490e+01, 1.3597e+01, 1.3973e+01,
#           1.2416e+01, 1.7847e+01, 1.7965e+01, 1.1426e+01, 4.5538e+00, 7.4827e+00,
#           7.4327e+00, 2.7716e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 4.4697e+00,
#           2.6626e+01, 2.9752e+01, 1.4703e+01, 5.5771e+00, 5.0182e+00, 7.9568e+00,
#           1.3544e-01, 3.8480e+00, 6.8352e+00, 3.1275e-02, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.1861e+00,
#           1.4603e+01, 2.5838e+01, 2.1235e+01, 1.7098e+01, 1.5432e+01, 1.2104e+01,
#           3.2632e+00, 3.5250e-02, 8.4158e-02, 3.6490e-01, 3.2250e-03, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.2492e-02,
#           0.0000e+00, 0.0000e+00, 1.3616e-01, 1.5885e-01, 5.5108e-01, 0.0000e+00,
#           0.0000e+00, 8.6878e-01, 0.0000e+00, 0.0000e+00, 1.0067e-02, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 6.3118e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           6.8419e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.6583e-03, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           3.0067e+00, 1.7204e+00, 0.0000e+00, 1.9109e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 4.7292e-02, 7.1333e-03, 9.2500e-04, 0.0000e+00]),
#   tensor([0., 0., 0., 0., 0.]))]

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=100, output_size=1):
        super().__init__()
        
        self.hidden_layer_size = hidden_layer_size

        self.lstm = nn.LSTM(input_size, hidden_layer_size,batch_first=True)

        self.linear = nn.Linear(hidden_layer_size, output_size)
        
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    def forward(self, input_seq):            
        batch_size, seq_len = input_seq.size()
        hidden_cell = (torch.zeros(1,batch_size,self.hidden_layer_size).to(self.device),
                       torch.zeros(1,batch_size,self.hidden_layer_size).to(self.device))
        #global save
        #save = input_seq
        lstm_out, hidden_cell = self.lstm(input_seq.view(len(input_seq) ,1, -1).swapaxes(1,2), hidden_cell)
        predictions = self.linear(lstm_out.reshape([batch_size*seq_len,lstm_out.shape[-1]]))
        #save = predictions
        predictions = predictions.view(seq_len, batch_size, -1)
        hidden_cell = [_.detach() for _ in hidden_cell]
        return predictions[-2]

# %%
# Custom loss for multi-point forecasting

def multiPointLoss(actual, predicted):
    scores = list()
    # calculate an RMSE score for each day
    for i in range(actual.shape[1]):
        # calculate mse
        mse = F.mse_loss(actual[:, i], predicted[:, i])
        # calculate rmse
        rmse = torch.sqrt(mse)
        # store
        scores.append(rmse)
    # calculate overall RMSE
    s = 0
    for row in range(actual.shape[0]):
        for col in range(actual.shape[1]):
            s += (actual[row, col] - predicted[row, col])**2
    score = torch.sqrt(s / (actual.shape[0] * actual.shape[1]))
    return score

# %%
x_list = [x[0] for x in train_inout_seq]
y_list = [x[1] for x in train_inout_seq]

# %%
torch.stack(x_list).shape
# Out:
# torch.Size([10715, 168])

# %%
import torch.utils.data as utils

dataset = utils.TensorDataset(torch.stack(x_list), torch.stack(y_list))
dataset

# %%
dataset.tensors[0].shape
# Out:
# torch.Size([10715, 168])

# %%
len(dataset)
# Out:
# 10715

# %%
from torch.utils.data import random_split

train_set, val_set = torch.utils.data.random_split(dataset, [round(len(dataset)*0.8), round(len(dataset)*0.2)])

# %%
# LSTM model init hidden state batch by batch. Therefore, data must not be shuffled

# Created using indices from 0 to train_size.
#train_set = torch.utils.data.Subset(dataset, range(int(len(dataset)*0.8)))

# Created using indices from train_size to train_size + test_size.
#val_set = torch.utils.data.Subset(dataset, range(int(len(dataset)*0.8), len(dataset)))

# %%
train_set

# %%
train_dls = utils.DataLoader(train_set, batch_size=1)
val_dls = utils.DataLoader(val_set, batch_size=1)

dls = DataLoaders(train_dls, val_dls)

# %%
model = LSTM(output_size=out_sz)
learn = Learner(dls, model, loss_func=multiPointLoss)
#learn = Learner(dls, model, loss_func=F.mse_loss)

# %%
learn.fine_tune(25, 2e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.463888</td>
#       <td>1.299508</td>
#       <td>02:32</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.438472</td>
#       <td>1.279004</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.440282</td>
#       <td>1.281610</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.455230</td>
#       <td>1.283287</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.466479</td>
#       <td>1.285039</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.482247</td>
#       <td>1.287723</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.462045</td>
#       <td>1.290756</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.470137</td>
#       <td>1.285908</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.473963</td>
#       <td>1.284731</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.463475</td>
#       <td>1.286117</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.474807</td>
#       <td>1.287412</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.458397</td>
#       <td>1.286602</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.455915</td>
#       <td>1.290837</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.457947</td>
#       <td>1.285008</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.450004</td>
#       <td>1.283009</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.440830</td>
#       <td>1.282631</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.444467</td>
#       <td>1.281810</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.433175</td>
#       <td>1.276289</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.428925</td>
#       <td>1.275416</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.427845</td>
#       <td>1.271697</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.409786</td>
#       <td>1.272897</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.413089</td>
#       <td>1.263335</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.408169</td>
#       <td>1.257245</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.389308</td>
#       <td>1.245910</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.375141</td>
#       <td>1.247653</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.356036</td>
#       <td>1.244423</td>
#       <td>02:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds,targs = learn.get_preds(dl=dls[1])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds.shape
# Out:
# torch.Size([2143, 5])

# %%
plt.figure(figsize=(100,6))
plt.plot(range(preds.shape[0]), preds[:,0])
plt.plot(range(preds.shape[0]), targs[:,0], 'r')
#plt.ylabel('Day Power')
#plt.legend(['Real Power', 'Predicted Power'])
plt.grid()
plt.show()

# %%
torch.save(learn, "models/LSTM_multipoint_new.pth")

# %% [markdown]
# # Test set

# %%
test_data = torch.FloatTensor(test_sequence).view(-1)

# %%
test_inout_seq = create_inout_sequences(test_data, train_window, out_sz)
len(test_inout_seq)
# Out:
# 479

# %%
test_x_list = [x[0] for x in test_inout_seq]
test_y_list = [x[1] for x in test_inout_seq]

# %%
test_dataset = utils.TensorDataset(torch.stack(test_x_list), torch.stack(test_y_list))
test_dataset

# %%
test_dls = utils.DataLoader(test_dataset, batch_size=1)
#val_dls = utils.DataLoader(val_set, batch_size=1)

#dls = DataLoaders(train_dls, val_dls)

# %%
preds,targs = learn.get_preds(dl=test_dls)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds.shape
# Out:
# torch.Size([479, 5])

# %%
plt.figure(figsize=(100,6))
plt.plot(range(preds.shape[0]), preds[:,0], 'r')
plt.plot(range(preds.shape[0]), targs[:,0])
#plt.ylabel('Day Power')
#plt.legend(['Real Power', 'Predicted Power'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(100,6))
plt.plot(range(preds.shape[0]), preds[:,4], 'r')
plt.plot(range(preds.shape[0]), targs[:,4])
#plt.ylabel('Day Power')
#plt.legend(['Real Power', 'Predicted Power'])
plt.grid()
plt.show()

# %%
multiPointLoss(targs, preds)
# Out:
# tensor(5.9522)

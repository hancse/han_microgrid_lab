# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab 
from datetime import datetime, timedelta
import numpy as np

# %%
data = pd.read_csv(r'./charge_hourly_with_Covid_new.csv')

# %%
data
# Out:
#                       Time  Energy_kWh  weekday  hour            hols  is_hol  \
# 0      2020-12-02 09:00:00    4.214567        2    10             NaN   False
# 1      2020-12-02 10:00:00    0.560625        2    11             NaN   False
# 2      2020-12-02 11:00:00    0.000000        2    12             NaN   False
# 3      2020-12-02 12:00:00    0.000000        2    13             NaN   False
# 4      2020-12-02 13:00:00    0.000558        2    14             NaN   False
# ...                    ...         ...      ...   ...             ...     ...
# 10883  2022-02-28 20:00:00    0.000000        0    21  Spring holiday    True
# 10884  2022-02-28 21:00:00    0.000000        0    22  Spring holiday    True
# 10885  2022-02-28 22:00:00    0.000000        0    23  Spring holiday    True
# 10886  2022-02-28 23:00:00    0.000000        1     0  Spring holiday    True
# 10887  2022-03-01 00:00:00    0.000000        1     1  Spring holiday    True
#
#        measure       E_1       E_2       E_3
# 0          3.0       NaN       NaN       NaN
# 1          3.0  4.214567       NaN       NaN
# 2          3.0  0.560625  4.214567       NaN
# 3          3.0  0.000000  0.560625  4.214567
# 4          3.0  0.000000  0.000000  0.560625
# ...        ...       ...       ...       ...
# 10883      0.0  0.000000  0.000000  0.000925
# 10884      0.0  0.000000  0.000000  0.000000
# 10885      0.0  0.000000  0.000000  0.000000
# 10886      0.0  0.000000  0.000000  0.000000
# 10887      0.0  0.000000  0.000000  0.000000
#
# [10888 rows x 10 columns]

# %%
patMon = data[data.weekday == 0].groupby(['hour']).mean()
patMon.reset_index(inplace=True)
patTue = data[data.weekday == 1].groupby(['hour']).mean()
patTue.reset_index(inplace=True)
patWed = data[data.weekday == 2].groupby(['hour']).mean()
patWed.reset_index(inplace=True)
patThu = data[data.weekday == 3].groupby(['hour']).mean()
patThu.reset_index(inplace=True)
patFri = data[data.weekday == 4].groupby(['hour']).mean()
patFri.reset_index(inplace=True)
patSat = data[data.weekday == 5].groupby(['hour']).mean()
patSat.reset_index(inplace=True)
patSun = data[data.weekday == 6].groupby(['hour']).mean()
patSun.reset_index(inplace=True)

# %%
patWeek_Avg = pd.concat([patMon, patTue, patWed, patThu, patFri, patSat, patSun])
patWeek_Avg.reset_index(inplace=True)

# %%
patWeek_Avg.drop(['index'], axis=1, inplace=True)

# %%
patWeek_Avg['Energy_kWh'].plot(figsize=(50,6), marker='o')
# Out:
# <AxesSubplot:>

# %%
patWeek_Avg.drop(['is_hol','measure','E_1','E_2','E_3'], axis=1, inplace=True)
patWeek_Avg
# Out:
#      hour  Energy_kWh  weekday
# 0       0    0.000000      0.0
# 1       1    0.000000      0.0
# 2       2    0.000000      0.0
# 3       3    0.000000      0.0
# 4       4    0.000000      0.0
# ..    ...         ...      ...
# 163    19    0.005972      6.0
# 164    20    0.002017      6.0
# 165    21    0.003842      6.0
# 166    22    0.000000      6.0
# 167    23    0.000000      6.0
#
# [168 rows x 3 columns]

# %%
def Predict12h(df_in):
    predictions = np.zeros(shape=(len(df_in)-12, 12))
    targets = np.zeros(shape=(len(df_in)-12, 12))
    Els = df_in['Energy_kWh']
    max_index = len(patWeek_Avg)
    for i in range(len(df_in)-12):
        weekday = df_in.weekday[i]
        hour = df_in.hour[i]
        index = patWeek_Avg[(patWeek_Avg.weekday == weekday) & (patWeek_Avg.hour == hour)]['Energy_kWh'].index[0]
        targets[i] = [Els[i+1], Els[i+2], Els[i+3], Els[i+4], Els[i+5], Els[i+6], Els[i+7], Els[i+8], Els[i+9], Els[i+10], Els[i+11], Els[i+12]]
        diff = Els[i] - patWeek_Avg.Energy_kWh[index]
        predictions[i] = [diff + patWeek_Avg.Energy_kWh[(index+1)%max_index],diff + patWeek_Avg.Energy_kWh[(index+2)%max_index],diff + patWeek_Avg.Energy_kWh[(index+3)%max_index],diff + patWeek_Avg.Energy_kWh[(index+4)%max_index],diff + patWeek_Avg.Energy_kWh[(index+5)%max_index], \
                         diff + patWeek_Avg.Energy_kWh[(index+6)%max_index],diff + patWeek_Avg.Energy_kWh[(index+7)%max_index],diff + patWeek_Avg.Energy_kWh[(index+8)%max_index],diff + patWeek_Avg.Energy_kWh[(index+9)%max_index],diff + patWeek_Avg.Energy_kWh[(index+10)%max_index], \
                         diff + patWeek_Avg.Energy_kWh[(index+11)%max_index],diff + patWeek_Avg.Energy_kWh[(index+12)%max_index]]
    return targets, predictions

# %%
targs, preds = Predict12h(data)

# %%
targs.shape
# Out:
# (10876, 12)

# %%
preds.shape
# Out:
# (10876, 12)

# %%
import torch.nn.functional as F

# Custom loss for multi-point forecasting

def multiPointLoss(actual, predicted):
    scores = list()
    # calculate an RMSE score for each day
    for i in range(actual.shape[1]):
        # calculate mse
        mse = F.mse_loss(actual[:, i], predicted[:, i])
        # calculate rmse
        rmse = torch.sqrt(mse)
        # store
        scores.append(rmse)
    # calculate overall RMSE
    s = 0
    for row in range(actual.shape[0]):
        for col in range(actual.shape[1]):
            s += (actual[row, col] - predicted[row, col])**2
    score = torch.sqrt(s / (actual.shape[0] * actual.shape[1]))
    return score

# %%
import torch

multiPointLoss(torch.tensor(targs), torch.tensor(preds))
# Out:
# tensor(3.5488, dtype=torch.float64)

# %%
plt.figure(figsize=(300,10))
plt.plot(range(len(targs)), targs[:,0])
plt.plot(range(len(preds)), preds[:,0], 'r')
plt.title('Performance on test set, prediction of hour +1')
plt.ylabel('Hourly charging demand')
plt.legend(['Real demand', 'Predicted demand'])
plt.grid()
plt.show()

# %% [markdown]
# # Test data

# %%
test_data = pd.read_csv(r'./charge0422_hourly_with_Covid_new.csv')

# %%
targs, preds = Predict12h(test_data)

# %%
multiPointLoss(torch.tensor(targs), torch.tensor(preds))
# Out:
# tensor(5.7735, dtype=torch.float64)

# %%
plt.figure(figsize=(100,6))
plt.plot(range(len(targs)), targs[:,0])
plt.plot(range(len(preds)), preds[:,0], 'r')
plt.title('Performance on test set, prediction of hour +1')
plt.ylabel('Hourly charging demand')
plt.legend(['Real demand', 'Predicted demand'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(100,6))
plt.plot(range(len(targs)), targs[:,1])
plt.plot(range(len(preds)), preds[:,1], 'r')
plt.title('Performance on test set, prediction of hour +2')
plt.ylabel('Hourly charging demand')
plt.legend(['Real demand', 'Predicted demand'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(100,6))
plt.plot(range(len(targs)), targs[:,11])
plt.plot(range(len(preds)), preds[:,11], 'r')
plt.title('Performance on test set, prediction of hour +12')
plt.ylabel('Hourly charging demand')
plt.legend(['Real demand', 'Predicted demand'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(100,6))
plt.plot(range(len(preds)-4), targs[4:,0] - preds[4:,0], 'g')
plt.plot(range(len(preds)-3), targs[3:,1] - preds[3:,1], 'y')
plt.plot(range(len(preds)-2), targs[2:,2] - preds[2:,2], 'r')
plt.plot(range(len(preds)-1), targs[1:,3] - preds[1:,3], 'b')
plt.plot(range(len(preds)), targs[:,4] - preds[:,4], 'k')
plt.title('Error of prediction')
plt.grid()
plt.show()

# %%
# Custom loss for multi-point forecasting

def multiPointLoss_hours(actual, predicted):
    scores = list()
    # calculate an RMSE score for each day
    for i in range(actual.shape[1]):
        # calculate mse
        mse = F.mse_loss(actual[:, i], predicted[:, i])
        # calculate rmse
        rmse = torch.sqrt(mse)
        # store
        scores.append(rmse)
    # calculate overall RMSE
    s = 0
    for row in range(actual.shape[0]):
        for col in range(actual.shape[1]):
            s += (actual[row, col] - predicted[row, col])**2
    score = torch.sqrt(s / (actual.shape[0] * actual.shape[1]))
    return scores

# %%
multiPointLoss_hours(torch.tensor(targs), torch.tensor(preds))
# Out:
# [tensor(2.9019, dtype=torch.float64),
#  tensor(4.4166, dtype=torch.float64),
#  tensor(5.2407, dtype=torch.float64),
#  tensor(5.6814, dtype=torch.float64),
#  tensor(5.9496, dtype=torch.float64),
#  tensor(6.1576, dtype=torch.float64),
#  tensor(6.2274, dtype=torch.float64),
#  tensor(6.2343, dtype=torch.float64),
#  tensor(6.2361, dtype=torch.float64),
#  tensor(6.2815, dtype=torch.float64),
#  tensor(6.3829, dtype=torch.float64),
#  tensor(6.5018, dtype=torch.float64)]

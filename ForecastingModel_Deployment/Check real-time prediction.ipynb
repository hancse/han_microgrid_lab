# %%
import pandas as pd # To load the data
import matplotlib.pyplot as plt # To draw figures
import matplotlib.pylab

# %%
data = pd.read_csv('demand_prediction(5).csv')

# %%
data
# Out:
#           Day  Weekday  Hour  E_LastHour       E_1       E_2        E_3  \
# 0    04/25/22        0    18    4.040208  1.581388  1.110606   0.871167
# 1    04/25/22        0    19    0.064200  0.850530  0.841088   0.741320
# 2    04/25/22        0    20    0.000000  0.341281  0.202242   0.139441
# 3    04/25/22        0    21    0.007217  0.494790  0.286880   0.172279
# 4    04/25/22        0    22    0.000000  0.430670  0.317583   0.336311
# ..        ...      ...   ...         ...       ...       ...        ...
# 319  05/09/22        0     1    0.000000  0.300961  0.226416   0.149971
# 320  05/09/22        0     2    0.000000  0.188068  0.169094   0.203787
# 321  05/09/22        0     3    0.000000  0.152905  0.225050   0.802701
# 322  05/09/22        0     4    0.000000  0.315925  0.917398   5.381944
# 323  05/09/22        0     5    0.000000  1.263604  6.140010  12.916814
#
#            E_4        E_5        E_6        E_7       E_8       E_9      E_10  \
# ...

# %%
data.shift(-1)['E_LastHour'].plot(figsize=(15,5))
data['E_1'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
data.shift(-12)['E_LastHour'].plot(figsize=(15,5))
data['E_12'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
data.shift(-6)['E_LastHour'].plot(figsize=(15,5))
data['E_6'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
data.shift(-3)['E_LastHour'].plot(figsize=(15,5))
data['E_3'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:>
